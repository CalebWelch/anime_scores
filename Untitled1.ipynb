# %%
from bs4 import BeautifulSoup as bsoup
from collections import defaultdict
import requests as rq
import json
import re
import pandas as pd

def getLines(showCount=0):
    loopCount = showCount/50
    data = {'genre':{},
	    'score':[]
	   }
    df = pd.DataFrame(data, index=[])
    print "starting"
    for i in range(0,loopCount):
        flag = True
        while flag:
            print i,loopCount,showCount
            try:
                page= rq.get('http://myanimelist.net/topanime.php?limit='+str(50*i))
                flag = False
            except Exception:
                flag = True
                print 'retrying loop'
            soup = bsoup(page.content,'html.parser')
            table = soup.find_all('tr',class_="ranking-list")
            shows = defaultdict(list)
            showName = []
            href = []
            for element in table:
                show = element.find('div',class_="di-ib clearfix")
                show.a['href']
                s = (show.a['href']).encode('utf-8').strip().split('/')[-1].replace('_',' ')
                href.append(show.a['href'])    
                showName.append(s)
                
            for index, name in enumerate(href):
                genre = {"Genre":""}
                print index, showName[index], len(href)
                page = rq.get(href[index])
                soup = bsoup(page.content,'html.parser')
                table = soup.find_all('div',class_='js-scrollfix-bottom')
                try:
                    genres =(table[0].find_all(text="Genres:")[0].parent.parent.find_all("a"))
                    score = soup.find_all('div',class_='fl-l score')[0].get_text(strip=True)
                except IndexError:
                    print "uh oh"
                    pass
                shows[showName[index]] = [[x.get_text() for x in genres], score]
            if len(shows) == 0:
                flag = True
            with open('anime_ratings.json','a+') as fp:
                json.dump(shows,fp)

def main():
    while True:
        numShows = input('Enter number of shoes as a multiple of 50 :: ')
        if numShows%50 is 0:
            break
        else:
            print "not a multiple of 50 :: "
            
    getLines(numShows)

if __name__ == "__main__":
    main()
# Out:
# Enter number of shoes as a multiple of 50 :: 50
# starting
# 0 1 50
# 0 Kimi no Na wa 50
# 1 Fullmetal Alchemist  Brotherhood 50
# 2 Gintama° 50
# 3 Steins Gate 50
# 4 Gintama 50
# 5 Hunter x Hunter 2011 50
# 6 Ginga Eiyuu Densetsu 50
# 7 Gintama  Enchousen 50
# 8 Gintama Movie  Kanketsu-hen - Yorozuya yo Eien Nare 50
# 9 Gintama 50
# 10 Clannad  After Story 50
# 11 Haikyuu  Karasuno Koukou VS Shiratorizawa Gakuen Koukou 50
# 12 Gintama 50
# 13 Koe no Katachi 50
# 14 Code Geass  Hangyaku no Lelouch R2 50
# 15 Shouwa Genroku Rakugo Shinjuu  Sukeroku Futatabi-hen 50
# 16 Sen to Chihiro no Kamikakushi 50
# 17 Haikyuu Second Season 50
# 18 Shigatsu wa Kimi no Uso 50
# 19 Mushishi Zoku Shou 2nd Season 50
# 20 Cowboy Bebop 50
# 21 Hajime no Ippo 50
# 22 Ookami Kodomo no Ame to Yuki 50
# 23 Rurouni Kenshin  Meiji Kenkaku Romantan - Tsuioku-hen 50
# 24 Code Geass  Hangyaku no Lelouch 50
# 25 Mononoke Hime 50
# 26 Natsume Yuujinchou Roku 50
# 27 Mushishi Zoku Shou 50
# 28 Suzumiya Haruhi no Shoushitsu 50
# 29 Kizumonogatari II  Nekketsu-hen 50
# 30 Monogatari Series  Second Season 50
# 31 One Punch Man 50
# 32 Mushishi 50
# 33 Great Teacher Onizuka 50
# 34 Tengen Toppa Gurren Lagann 50
# 35 Hajime no Ippo  New Challenger 50
# 36 Howl no Ugoku Shiro 50
# 37 Mushishi Zoku Shou  Suzu no Shizuku 50
# 38 Natsume Yuujinchou Shi 50
# 39 Kizumonogatari III  Reiketsu-hen 50
# 40 Shingeki no Kyojin Season 2 50
# 41 Bakuman 3rd Season 50
# 42 Death Note 50
# 43 Fate Zero 2nd Season 50
# 44 Monster 50
# 45 Haikyuu 50
# 46 Hajime no Ippo  Rising 50
# 47 Ansatsu Kyoushitsu TV 2nd Season 50
# 48 JoJo no Kimyou na Bouken  Diamond wa Kudakenai 50
# 49 Kara no Kyoukai 5  Mujun Rasen 50

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7ed0097d7e9e> in <module>()
# ----> 1 df
#
# NameError: name 'df' is not defined
