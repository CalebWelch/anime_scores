# %%
import seaborn as sb
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('file_name')

# %%
del df[df.columns[0]]
df.Score = [float(x.split(' ')[1]) for x in df.Score]

# %%
fig, axs = plt.subplots(ncols=2,figsize=(9,6))
sb.countplot(x=df.Type, data = df,ax=axs[0])
sb.swarmplot(x=df.Type,y=df.Popularity, ax=axs[1])

# %% [markdown]
# <p>Seems like there is a weird disconnect between the popularity of the show vs it's rank

# %%
sb.regplot(x=df.Popularity, y=df.Ranked,color="Black",fit_reg=False,scatter=True,)

# %% [markdown]
# Calculating the Z values for popularity and score

# %%
float_numbers = [float(x.split(' ')[1]) for x in df.Score]
avg = np.average(float_numbers)

div = 1.0/len(df.Score)
stddev = np.sqrt(div*np.sum([np.square(x - avg) for x in float_numbers]))
print stddev
z_scores_score = [(x-avg)/stddev for x in float_numbers]
# Out:
# 0.179768851584

# %%
float_numbers = [float(x) for x in df.Popularity]
avg = np.average(float_numbers)
stddev = np.sqrt(div*np.sum([np.square(x - avg) for x in float_numbers]))
print stddev
z_scores_pop = [(x-avg)/stddev for x in float_numbers]
# Out:
# 436.899494621

# %%
z_scores_score = np.array(z_scores_score)
z_scores_pop = np.array(z_scores_pop)
sb.regplot(x= z_scores_score,y=z_scores_pop,fit_reg=False)
plt.xlabel('z score for scores')
plt.ylabel('z score for popularity')

# %%
genre = set()
for x in df.Genres:
     for l in [k.split(',')[0][1:] for k in  x.split(',')]:
            genre.add(l)

# %%
scoredf = pd.DataFrame(index=genre)
for x in df.Genres:
    for k in genre:
        if k in x:
            scoredf.loc[k] += df.Score[k.index]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-99d645263945> in <module>()
#       3     for k in genre:
#       4         if k in x:
# ----> 5             scoredf.loc[k] += df.Score[k.index]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in __getitem__(self, key)
#     599
#     600     def __getitem__(self, key):
# --> 601         key = com._apply_if_callable(key, self)
#     602         try:
#     603             result = self.index.get_value(self, key)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/common.pyc in _apply_if_callable(maybe_callable, obj, **kwargs)
#     451     """
#     452     if callable(maybe_callable):
# --> 453         return maybe_callable(obj, **kwargs)
#     454     return maybe_callable
#     455
#
# TypeError: expected a character buffer object

# %%
scoredf
# Out:
# Empty DataFrame
# Columns: [Police, Sci-Fi, Space, Vampire, Sports, Romance, Supernatural, Comedy, Josei, Mecha, Slice of Life, Horror, Shoujo, Adventure, Thriller, Mystery, School, Magic, Drama, Samurai, Historical, Action, Military, Parody, Seinen, Shounen, Psychological, Fantasy, Music, Martial Arts, Super Power]
# Index: []
#
# [0 rows x 31 columns]
